# %% [markdown]
# ## 준비

# %%
import os
os.chdir('C:/Users/syjan/Desktop/암연구소 인턴/CRC_research') #디렉토리 입력

# %%
#필요한 패키지 다운로드
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
from sklearn.preprocessing import StandardScaler, RobustScaler

# %% [markdown]
# ## 데이터 설명
#
# ### 1) df1
# - `CAN_ID` : 환자 ID
# - `food_group`: 식품군 번호 (1~36)
# - `food_group_name`: 식품군명
# - `energy`: 환자별 해당 식품군 내 식품으로 섭취한 에너지량 (kcal)
# - `energy_new` : 잔차법을 적용해 보정한 에너지량 (kcal)
# - `energy_total`: 환자별 섭취한 에너지량 총합 (kcal)

# %%
df1 = pd.read_csv('sum_by_food_group.csv').drop(columns=['res', 'b0', 'b1', 'mu_hat'])
df1.head()
# Out:
#   CAN_ID  food_group     food_group_name       energy  energy_total  \
# 0   A001           1      Refined grains  1346.400000   2244.810576
# 1   A001           3    Tubers and roots    18.334477   2244.810576
# 2   A001           4             Noodles   129.534377   2244.810576
# 3   A001           6               Bread    15.651144   2244.810576
# 4   A001           7  Cereals and snacks   298.258006   2244.810576
#
#     energy_new
# 0  1096.872000
# 1     7.487928
# 2    52.027101
# 3     6.630994
# 4   130.946536

# %%
food_group_info = df1[['food_group', 'food_group_name']].drop_duplicates().sort_values(by='food_group').reset_index(drop=True)
food_group_info['food_group'] = food_group_info['food_group'].apply(lambda x: 'g'+str(x))
food_group_name = food_group_info.food_group_name.tolist()
food_group_info
# Out:
#    food_group              food_group_name
# 0          g1               Refined grains
# 1          g2                 Whole grains
# 2          g3             Tubers and roots
# 3          g4                      Noodles
# 4          g5                   Rice cakes
# 5          g6                        Bread
# 6          g7           Cereals and snacks
# 7          g8          Pizza and hamburger
# 8          g9             Cakes and sweets
# 9         g10                      Legumes
# 10        g11            Tofu and soy milk
# 11        g12               Nuts and seeds
# 12        g13                     Red meat
# 13        g14             Meat by-products
# 14        g15               Processed meat
# 15        g16                      Poultry
# 16        g17                         Fish
# 17        g18             Seafood products
# 18        g19                Other seafood
# 19        g20     Salted fermented seafood
# 20        g21                     Seaweeds
# 21        g22                         Eggs
# 22        g23                         Milk
# 23        g24               Dairy Products
# 24        g25                       Fruits
# 25        g26               Fruit products
# 26        g27  Green and yellow vegetables
# 27        g28     Light-colored vegetables
# 28        g29           Pickled vegetables
# 29        g30                       Kimchi
# 30        g31                    Mushrooms
# 31        g32                  Oil and fat
# 32        g33    Condiments and seasonings
# 33        g34         Carbonated beverages
# 34        g35               Coffee and tea
# 35        g36                      Alcohol

# %% [markdown]
# ### 2) df2
# : df1의 pivot버전
# - `energy_total`: 섭취한 에너지량 총합 (kcal)
# - `g1` ~ `g36` : 보정된 식품군별 에너지량 (kcal, df1의 `energy_new`에 해당)

# %%
df2 = pd.read_csv('sum_by_food_group_table.csv').set_index('CAN_ID')
df2.head()
# Out:
#               total           g1         g2         g3          g4         g5  \
# CAN_ID
# A001    2244.810576  1346.400000   0.000000  18.334477  129.534377   0.000000
# A002    2436.418370   911.573987   0.000000  66.166072  149.562567  19.748695
# A003    3101.255659   883.243942   0.000000  91.871602  149.126573  11.948805
# A004    1336.675140  1023.666524  52.773881  16.434117    6.599340   0.000000
# A005    1338.475603  1023.666524  52.773881  30.360000    0.000000   0.000000
#
#                 g6          g7         g8          g9  ...        g27  \
# CAN_ID                                                 ...
# A001     15.651144  298.258006   0.000000   27.406121  ...  12.916375
# A002     58.921957   40.671201  23.009699   44.966175  ...  18.852229
# A003    109.873984   81.342402  19.175900   44.602726  ...  30.412574
# A004      0.000000    0.000000   0.000000  113.873478  ...   5.811823
# A005      0.000000    0.000000   0.000000    1.313243  ...  14.361302
#
#               g28        g29        g30        g31        g32        g33  \
# CAN_ID
# A001    37.131189   0.168315  25.061163   1.323816  43.973395  24.580354
# A002    22.698361   0.425078  14.482327   2.751451  56.066489  27.588250
# A003    43.638385  31.966620  68.841489  14.030298  49.185521  47.455013
# A004    13.447546   0.947233  10.908022   0.988062   1.018383  13.822185
# A005    13.759201   1.692008  15.211686   0.396651   2.388571  27.956693
#
#              g34        g35  g36
# CAN_ID
# A001    0.000000  14.934586  0.0
# A002    0.000000  28.512000  0.0
# A003    6.771062  29.898307  0.0
# A004    0.000000   8.141236  0.0
# A005    0.000000  19.008000  0.0
#
# [5 rows x 37 columns]

# %%
x = df2.drop(columns=['total'])
#StandardScaler() : 열마다 평균이 0, 표쥰편차가 1이 되도록 변환
x_scaled = StandardScaler().fit_transform(x)
x_scaled
# Out:
# array([[ 1.85897336, -0.96355857, -0.39725468, ..., -0.29287958,
#         -0.41050694, -0.07454139],
#        [ 0.43264211, -0.96355857,  0.48270751, ..., -0.29287958,
#         -0.24573149, -0.07454139],
#        [ 0.33971292, -0.96355857,  0.95561448, ..., -0.04506606,
#         -0.22890728, -0.07454139],
#        ...,
#        [ 0.61190211,  0.1297616 , -0.05080319, ..., -0.29287958,
#         -0.11405217, -0.07454139],
#        [ 1.8681404 , -0.96355857, -0.42108271, ..., -0.04506606,
#         -0.26227   , -0.07454139],
#        [ 0.61190211,  0.1297616 , -0.60670835, ..., -0.19376012,
#          0.19909203, -0.07454139]])

# %% [markdown]
# ## 식이패턴 분석
# ### 1) PCA

# %%
from sklearn.decomposition import PCA
#from pca import pca

# %%
pca = PCA().fit(x_scaled)

def scree_plot_pca(pca): 
    num_components = len(pca.explained_variance_ratio_) 
    ind = np.arange(num_components) 
    vals = pca.explained_variance_ratio_ 
    plt.plot(ind, vals)
    plt.scatter(ind, vals)
    plt.xlabel("PC") 
    plt.ylabel("Variance") 
    plt.title('Scree plot')

scree_plot_pca(pca)

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.31499435, 0.38658828, 0.4355902 , 0.47615266, 0.51401469,
#        0.54798081, 0.58018157, 0.6110898 , 0.6407479 , 0.6675299 ,
#        0.69154993, 0.71446347, 0.73610941, 0.75681178, 0.77592021,
#        0.79457476, 0.81226846, 0.82864799, 0.84432327, 0.85927719,
#        0.87363573, 0.8866703 , 0.89932321, 0.91164561, 0.92336864,
#        0.93425895, 0.94456319, 0.95438862, 0.96210228, 0.96947126,
#        0.9767046 , 0.98250312, 0.98776501, 0.99273452, 0.99708974,
#        1.        ])

# %%
pca_out = PCA(n_components=3).fit(x_scaled)
loadings =  pca_out.components_
num_pc = pca_out.n_features_
pc_list = ["PC"+str(i) for i in list(range(1, num_pc+1))]
loadings_df = pd.DataFrame.from_dict(dict(zip(pc_list, loadings)))
loadings_df['food_group_name'] = food_group_name
loadings_df = loadings_df.set_index('food_group_name')
loadings_df[['PC1', 'PC2', 'PC3']].style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style  type="text/css" >
# #T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row0_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row1_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row2_col2,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row3_col1,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row4_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row5_col1,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row6_col1,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row7_col1,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row8_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row9_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row10_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row11_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row12_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row13_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row14_col1,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row15_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row16_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row17_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row18_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row19_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row20_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row21_col2,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row22_col2,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row23_col2,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row24_col2,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row25_col2,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row26_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row27_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row28_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row29_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row30_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row31_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row32_col0,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row33_col1,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row34_col2,#T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row35_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PC1</th>        <th class="col_heading level0 col1" >PC2</th>        <th class="col_heading level0 col2" >PC3</th>    </tr>    <tr>        <th class="index_name level0" >food_group_name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row0" class="row_heading level0 row0" >Refined grains</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row0_col0" class="data row0 col0" >0.046763</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row0_col1" class="data row0 col1" >-0.137567</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row0_col2" class="data row0 col2" >-0.515440</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row1" class="row_heading level0 row1" >Whole grains</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row1_col0" class="data row1 col0" >0.072102</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row1_col1" class="data row1 col1" >-0.213412</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row1_col2" class="data row1 col2" >-0.377160</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row2" class="row_heading level0 row2" >Tubers and roots</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row2_col0" class="data row2 col0" >0.152110</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row2_col1" class="data row2 col1" >-0.194688</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row2_col2" class="data row2 col2" >0.169862</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row3" class="row_heading level0 row3" >Noodles</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row3_col0" class="data row3 col0" >0.179071</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row3_col1" class="data row3 col1" >0.271476</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row3_col2" class="data row3 col2" >-0.089737</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row4" class="row_heading level0 row4" >Rice cakes</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row4_col0" class="data row4 col0" >0.151214</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row4_col1" class="data row4 col1" >0.024712</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row4_col2" class="data row4 col2" >-0.045099</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row5" class="row_heading level0 row5" >Bread</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row5_col0" class="data row5 col0" >0.123901</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row5_col1" class="data row5 col1" >0.247861</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row5_col2" class="data row5 col2" >0.129319</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row6" class="row_heading level0 row6" >Cereals and snacks</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row6_col0" class="data row6 col0" >0.096337</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row6_col1" class="data row6 col1" >0.244348</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row6_col2" class="data row6 col2" >0.118490</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row7" class="row_heading level0 row7" >Pizza and hamburger</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row7_col0" class="data row7 col0" >0.195013</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row7_col1" class="data row7 col1" >0.249977</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row7_col2" class="data row7 col2" >-0.111010</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row8" class="row_heading level0 row8" >Cakes and sweets</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row8_col0" class="data row8 col0" >0.207120</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row8_col1" class="data row8 col1" >0.171112</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row8_col2" class="data row8 col2" >-0.023812</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row9" class="row_heading level0 row9" >Legumes</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row9_col0" class="data row9 col0" >0.093816</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row9_col1" class="data row9 col1" >-0.116246</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row9_col2" class="data row9 col2" >-0.153391</td>
#             </tr>
#             <tr>
#                         <th id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66level0_row10" class="row_heading level0 row10" >Tofu and soy milk</th>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row10_col0" class="data row10 col0" >0.170893</td>
#                         <td id="T_b68b2e1a_0f32_11ed_b870_fcba2c072a66row10_col1" class="data row10 col

# %%
#PC score for each obsv (patient)
x_pca=pca_out.fit_transform(x_scaled)
pca_columns=['PC1','PC2', 'PC3']
pca_result = pd.DataFrame(x_pca,columns=pca_columns)
pca_result['CAN_ID'] = df2.index
pca_result.head()
# Out:
#         PC1       PC2       PC3 CAN_ID
# 0 -0.498243  1.119537 -0.872761   A001
# 1  0.120467  0.960928  0.389467   A002
# 2  5.785487 -2.886207  0.392392   A003
# 3 -2.185346 -0.112256 -1.535354   A004
# 4 -2.195263 -0.727181 -1.361883   A005

# %%
plt.figure(figsize=(8,8))
sns.heatmap(loadings_df, cmap='Greens')
plt.title("Correlation heatmap of principal component loadings")
plt.ylabel("")
plt.show()

# %%
def myplot(score,coeff, p1, p2, labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    #min-max scaling for better visualization
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    
    #plot
    plt.figure(figsize=(10,10))
    plt.scatter(xs * scalex,ys * scaley,s=5)
    for i in range(n):
        if abs(coeff[i,0])>0.2 or abs(coeff[i,1])>0.2:
            plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
            if labels is None:
                plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
            else:
                plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(p1))
    plt.ylabel("PC{}".format(p2))
    plt.grid()

myplot(x_pca[:,0:2], np.transpose(pca_out.components_[0:2, :]),1,2,food_group_name)
plt.show()

# %%
myplot(x_pca[:,1:3],np.transpose(pca_out.components_[1:3, :]),2,3,food_group_name)

# %%
myplot(x_pca[:,[0,2]],np.transpose(pca_out.components_[1:3, :]),1,3,food_group_name)

# %% [markdown]
# ### 2) Exploratory Factor Analysis

# %%
from factor_analyzer import FactorAnalyzer, calculate_bartlett_sphericity, calculate_kmo

# %% [markdown]
# #### Assumption checking

# %% [markdown]
# 1. Bartlett’s test of sphericity
# - checks whether or not the observed variables intercorrelate at all using the observed correlation matrix against the identity matrix.
# - If the test found statistically insignificant, you should not employ a factor analysis.
# - The test was statistically significant, indicating that the observed correlation matrix is not an identity matrix.

# %%
calculate_bartlett_sphericity(x) #Bartlett's test significant
# Out:
# (9804.989215495872, 0.0)

# %% [markdown]
# 2. Kaiser-Meyer-Olkin (KMO) Test
# - measures the suitability of data for factor analysis.
# - determines the adequacy for each observed variable and for the complete model.
# - KMO estimates the proportion of variance among all the observed variable, and range between 0 and 1. Lower proportion id more suitable for factor analysis.
# - Value of KMO less than 0.6 is considered inadequate.

# %%
calculate_kmo(x) #kmo > 0.6
# Out:
# (array([0.63669196, 0.72638758, 0.92951908, 0.93069009, 0.87067337,
#         0.77259173, 0.71511371, 0.93261143, 0.92919524, 0.79535685,
#         0.9350809 , 0.92506525, 0.90732206, 0.92599251, 0.9268387 ,
#         0.93889768, 0.90175289, 0.93198589, 0.91825905, 0.93967263,
#         0.91361443, 0.93846945, 0.78472497, 0.89779414, 0.81481295,
#         0.80120626, 0.9174838 , 0.91322   , 0.86192773, 0.83550502,
#         0.9174984 , 0.93401397, 0.92896758, 0.85738107, 0.86996521,
#         0.92637975]),
#  0.9015391763352042)

# %% [markdown]
# #### Get appropriate # of factors

# %%
fa = FactorAnalyzer(36, rotation=None)
fa.fit(x)

def scree_plot_fa(fa): 
    ind = np.arange(36) 
    vals, n = fa.get_eigenvalues()
    plt.plot(ind, vals)
    plt.scatter(ind, vals)
    plt.xlabel('Factors')
    plt.ylabel('Eigenvalue')
    plt.title('Scree plot')

scree_plot_fa(fa) #Choose n_factors=3

# %% [markdown]
# #### With varimax rotation

# %%
fa = FactorAnalyzer(n_factors=3,rotation='varimax')
fa.fit(x)
factor_df=pd.DataFrame(fa.loadings_,index=food_group_name)
factor_df.columns= ['F1', 'F2', 'F3']
factor_df.style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style  type="text/css" >
# #T_b0591d63_0f34_11ed_9821_fcba2c072a66row0_col2,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row1_col2,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row2_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row3_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row4_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row5_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row6_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row7_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row8_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row9_col2,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row10_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row11_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row12_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row13_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row14_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row15_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row16_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row17_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row18_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row19_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row20_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row21_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row22_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row23_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row24_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row25_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row26_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row27_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row28_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row29_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row30_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row31_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row32_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row33_col0,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row34_col1,#T_b0591d63_0f34_11ed_9821_fcba2c072a66row35_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_b0591d63_0f34_11ed_9821_fcba2c072a66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >F1</th>        <th class="col_heading level0 col1" >F2</th>        <th class="col_heading level0 col2" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row0" class="row_heading level0 row0" >Refined grains</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row0_col0" class="data row0 col0" >0.031016</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row0_col1" class="data row0 col1" >-0.066830</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row0_col2" class="data row0 col2" >0.620271</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row1" class="row_heading level0 row1" >Whole grains</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row1_col0" class="data row1 col0" >0.002660</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row1_col1" class="data row1 col1" >0.123868</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row1_col2" class="data row1 col2" >0.530541</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row2" class="row_heading level0 row2" >Tubers and roots</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row2_col0" class="data row2 col0" >0.133004</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row2_col1" class="data row2 col1" >0.572598</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row2_col2" class="data row2 col2" >0.088629</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row3" class="row_heading level0 row3" >Noodles</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row3_col0" class="data row3 col0" >0.709220</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row3_col1" class="data row3 col1" >0.113384</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row3_col2" class="data row3 col2" >0.077770</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row4" class="row_heading level0 row4" >Rice cakes</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row4_col0" class="data row4 col0" >0.370170</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row4_col1" class="data row4 col1" >0.276061</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row4_col2" class="data row4 col2" >0.163829</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row5" class="row_heading level0 row5" >Bread</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row5_col0" class="data row5 col0" >0.490851</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row5_col1" class="data row5 col1" >0.148563</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row5_col2" class="data row5 col2" >-0.144586</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row6" class="row_heading level0 row6" >Cereals and snacks</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row6_col0" class="data row6 col0" >0.417322</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row6_col1" class="data row6 col1" >0.087197</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row6_col2" class="data row6 col2" >-0.144097</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row7" class="row_heading level0 row7" >Pizza and hamburger</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row7_col0" class="data row7 col0" >0.737672</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row7_col1" class="data row7 col1" >0.143427</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row7_col2" class="data row7 col2" >0.135003</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row8" class="row_heading level0 row8" >Cakes and sweets</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row8_col0" class="data row8 col0" >0.657050</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row8_col1" class="data row8 col1" >0.302212</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row8_col2" class="data row8 col2" >0.094304</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row9" class="row_heading level0 row9" >Legumes</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row9_col0" class="data row9 col0" >0.121769</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row9_col1" class="data row9 col1" >0.214631</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row9_col2" class="data row9 col2" >0.255719</td>
#             </tr>
#             <tr>
#                         <th id="T_b0591d63_0f34_11ed_9821_fcba2c072a66level0_row10" class="row_heading level0 row10" >Tofu and soy milk</th>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row10_col0" class="data row10 col0" >0.210505</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row10_col1" class="data row10 col1" >0.565931</td>
#                         <td id="T_b0591d63_0f34_11ed_9821_fcba2c072a66row10_col2" class="data row10 col2" >0.134293</td>
#             </tr>
#             <tr>

# %%
plt.figure(figsize=(8,8))
sns.heatmap(factor_df, cmap='Greens')
plt.title("Correlation heatmap of factor loadings")
plt.ylabel("")
plt.show()

# %% [markdown]
# #### With oblimin rotation

# %%
fa = FactorAnalyzer(n_factors=3,rotation='oblimin')
fa.fit(x)
factor_df=pd.DataFrame(fa.loadings_,index=food_group_name)
factor_df.columns= ['F1', 'F2', 'F3']
factor_df.style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style  type="text/css" >
# #T_a64234b6_0f34_11ed_afd0_fcba2c072a66row0_col2,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row1_col2,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row2_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row3_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row4_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row5_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row6_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row7_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row8_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row9_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row10_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row11_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row12_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row13_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row14_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row15_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row16_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row17_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row18_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row19_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row20_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row21_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row22_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row23_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row24_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row25_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row26_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row27_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row28_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row29_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row30_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row31_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row32_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row33_col1,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row34_col0,#T_a64234b6_0f34_11ed_afd0_fcba2c072a66row35_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >F1</th>        <th class="col_heading level0 col1" >F2</th>        <th class="col_heading level0 col2" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row0" class="row_heading level0 row0" >Refined grains</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row0_col0" class="data row0 col0" >-0.020323</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row0_col1" class="data row0 col1" >0.068994</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row0_col2" class="data row0 col2" >0.618644</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row1" class="row_heading level0 row1" >Whole grains</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row1_col0" class="data row1 col0" >0.207996</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row1_col1" class="data row1 col1" >-0.045725</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row1_col2" class="data row1 col2" >0.481261</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row2" class="row_heading level0 row2" >Tubers and roots</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row2_col0" class="data row2 col0" >0.651363</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row2_col1" class="data row2 col1" >-0.087944</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row2_col2" class="data row2 col2" >-0.085871</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row3" class="row_heading level0 row3" >Noodles</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row3_col0" class="data row3 col0" >-0.098616</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row3_col1" class="data row3 col1" >0.777923</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row3_col2" class="data row3 col2" >-0.025864</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row4" class="row_heading level0 row4" >Rice cakes</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row4_col0" class="data row4 col0" >0.222730</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row4_col1" class="data row4 col1" >0.314725</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row4_col2" class="data row4 col2" >0.046143</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row5" class="row_heading level0 row5" >Bread</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row5_col0" class="data row5 col0" >-0.006716</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row5_col1" class="data row5 col1" >0.507173</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row5_col2" class="data row5 col2" >-0.230291</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row6" class="row_heading level0 row6" >Cereals and snacks</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row6_col0" class="data row6 col0" >-0.055039</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row6_col1" class="data row6 col1" >0.447671</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row6_col2" class="data row6 col2" >-0.205524</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row7" class="row_heading level0 row7" >Pizza and hamburger</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row7_col0" class="data row7 col0" >-0.065836</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row7_col1" class="data row7 col1" >0.798686</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row7_col2" class="data row7 col2" >0.018641</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row8" class="row_heading level0 row8" >Cakes and sweets</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row8_col0" class="data row8 col0" >0.147712</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row8_col1" class="data row8 col1" >0.637046</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row8_col2" class="data row8 col2" >-0.057045</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row9" class="row_heading level0 row9" >Legumes</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row9_col0" class="data row9 col0" >0.244756</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row9_col1" class="data row9 col1" >0.052353</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row9_col2" class="data row9 col2" >0.177071</td>
#             </tr>
#             <tr>
#                         <th id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66level0_row10" class="row_heading level0 row10" >Tofu and soy milk</th>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row10_col0" class="data row10 col0" >0.621948</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row10_col1" class="data row10 col1" >0.005435</td>
#                         <td id="T_a64234b6_0f34_11ed_afd0_fcba2c072a66row10_col2" class="data row10 col2" >-0.047268</td>
#             </tr>
#             <tr>

# %% [markdown]
# ### 3) K-means clustering

# %%
from sklearn.cluster import KMeans
from kneed import KneeLocator
from sklearn.metrics import silhouette_score

# %%
wcss=[]
for k in range(2,8):
    kmeans = KMeans(
        init="k-means++", #look for convergence
        n_clusters = k,
        max_iter=300,
        algorithm='auto', #lloyd algorithm
        random_state=2022)
    kmeans.fit(x_scaled)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

def scree_plot_kmeans(wcss):
    k = range(2,8)
    plt.plot(k,wcss)
    plt.scatter(k,wcss)
    plt.title('Scree Plot')
    plt.xlabel('# of clusters')
    plt.ylabel('WCSS')
    
scree_plot_kmeans(wcss)

# %%
k_means = KMeans(init="k-means++", n_clusters=3)
k_means.fit(x_scaled)
# Out:
# KMeans(n_clusters=3)

# %%
print("Lowest SSE value: ",k_means.inertia_)
#print("Centroids for each center: ",k_means.cluster_centers_)
print("The number of iterations required to converge:", k_means.n_iter_)
# Out:
# Lowest SSE value:  14022.03773908802
# The number of iterations required to converge: 12

# %% [markdown]
# ### Hierarchical Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
linked = linkage(x_scaled.transpose(), 'ward')
labels = food_group_name

plt.figure(figsize=(17, 10))
dendrogram(linked,labels=labels)
plt.axhline(y=40, c='k', linestyle='--') 
plt.show()

# %% [markdown]
# ## 생존분석

# %% [markdown]
# ## 참고자료
# - [식품군 분류 기준](https://www.sciencedirect.com/science/article/abs/pii/S2212267220314581?via%3Dihub)
# - [Factor Analysis using Python](https://www.datacamp.com/tutorial/introduction-factor-analysis)
